# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import ScalarFormatter, FormatStrFormatter
from scipy.stats import norm
import matplotlib as mpl

# %%
Despoblacion = pd.read_excel('graficos.xlsx', dtype='object')

# %%
Despoblacion
# Out:
#      Nombre Provincia Codigo Provincia Nombre Municipio Codigo Municipio  \
# 0            Albacete               02        Abengibre            02001
# 1            Albacete               02         Albacete            02003
# 2            Albacete               02         Albatana            02004
# 3            Albacete               02          Almansa            02009
# 4            Albacete               02           Alpera            02010
# ...               ...              ...              ...              ...
# 3980         Zaragoza               50        Zaida, La            50296
# 3981         Zaragoza               50         Zaragoza            50297
# 3982         Zaragoza               50            Zuera            50298
# 3983            Ceuta               51            Ceuta            51001
# 3984          Melilla               52          Melilla            52001
#
#      Poblacion Total Poblacion Hombre Poblacion Mujer Superficie Km2_x  \
# ...

# %%
Columnas = Despoblacion.columns[4 : ]
Despoblacion[Columnas] = round(Despoblacion[Columnas].apply(pd.to_numeric), 2)

# %%
pd.set_option('display.max_columns', None)

# %%
Despoblacion.head()
# Out:
#   Nombre Provincia Codigo Provincia Nombre Municipio Codigo Municipio  \
# 0         Albacete               02        Abengibre            02001
# 1         Albacete               02         Albacete            02003
# 2         Albacete               02         Albatana            02004
# 3         Albacete               02          Almansa            02009
# 4         Albacete               02           Alpera            02010
#
#    Poblacion Total  Poblacion Hombre  Poblacion Mujer  Superficie Km2_x  \
# 0              902               457              445             30.77
# 1           171390             84288            87102           1126.99
# 2              794               403              391             30.50
# 3            25432             12631            12801            531.82
# 4             2438              1261             1177            178.47
#
#    Densidad Poblacion_x  Altitud Municipios  Nacimientos  Matrimonios  \
# ...

# %%
Despoblacion['Umbral1'] = Despoblacion['Umbral'].map(lambda x: 'Despo' if x==0 else 'Pobla')

# %%
Despoblacion.head()
# Out:
#   Nombre Provincia Codigo Provincia Nombre Municipio Codigo Municipio  \
# 0         Albacete               02        Abengibre            02001
# 1         Albacete               02         Albacete            02003
# 2         Albacete               02         Albatana            02004
# 3         Albacete               02          Almansa            02009
# 4         Albacete               02           Alpera            02010
#
#    Poblacion Total  Poblacion Hombre  Poblacion Mujer  Superficie Km2_x  \
# 0              902               457              445             30.77
# 1           171390             84288            87102           1126.99
# 2              794               403              391             30.50
# 3            25432             12631            12801            531.82
# 4             2438              1261             1177            178.47
#
#    Densidad Poblacion_x  Altitud Municipios  Nacimientos  Matrimonios  \
# ...

# %%
Despoblacion['porcenhom'] = (Despoblacion['Poblacion Hombre'] / Despoblacion['Poblacion Total'])*100

# %%
Despoblacion['porcenmuje'] = (Despoblacion['Poblacion Mujer'] / Despoblacion['Poblacion Total'])*100
print(Despoblacion['porcenmuje'].mean())
print(Despoblacion['porcenmuje'].median())

print(f"Skewness: {Despoblacion['porcenmuje'].skew()}")
print(f"Kurtosis: {Despoblacion['porcenmuje'].kurt()}")

fig,ax = plt.subplots(figsize=(6,6))
##ax.get_xaxis().get_major_formatter().set_scientific(False)
#plt.gca().set_xscale('log')
ax.hist(Despoblacion['porcenmuje'], bins = 20)
#ax.plot(x, normal_pdf)
ax.set_xlim(40, 60)
ax.set_xlabel('Población Mujeres')
plt.show()
# Out:
# 49.02524463802712
# 49.266862170087975
# Skewness: -1.012959597450134
# Kurtosis: 4.184739690576219

# %%
Despoblacion['porcenhom'] = (Despoblacion['Poblacion Hombre'] / Despoblacion['Poblacion Total'])*100
print(Despoblacion['porcenhom'].mean())
print(Despoblacion['porcenhom'].median())

print(f"Skewness: {Despoblacion['porcenhom'].skew()}")
print(f"Kurtosis: {Despoblacion['porcenhom'].kurt()}")

fig,ax = plt.subplots(figsize=(6,6))
##ax.get_xaxis().get_major_formatter().set_scientific(False)
#plt.gca().set_xscale('log')
ax.hist(Despoblacion['porcenhom'], bins = 20)
#ax.plot(x, normal_pdf)
ax.set_xlim(40, 60)
ax.set_xlabel('Población Mujeres')
plt.show()
# Out:
# 50.974755361972875
# 50.733137829912025
# Skewness: 1.0129595974501335
# Kurtosis: 4.184739690576219

# %%
plt.hist(Despoblacion['porcenhom'], bins=30,density=True);
plt.hist(Despoblacion['porcenmuje'], bins=30,density=True,alpha=0.5);

# %%
fig,ax=plt.subplots(figsize=(6,6))

ax2=ax.twinx()
ax.hist(Despoblacion['porcenhom'], bins = 20)
ax2.hist(Despoblacion['porcenmuje'], bins = 20,alpha=0.5)
# Out:
# (array([4.000e+00, 0.000e+00, 2.000e+00, 8.000e+00, 2.500e+01, 5.100e+01,
#         8.200e+01, 2.300e+02, 5.910e+02, 1.240e+03, 1.256e+03, 4.000e+02,
#         7.800e+01, 1.600e+01, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([35.43956044, 36.84677317, 38.2539859 , 39.66119863, 41.06841136,
#         42.47562409, 43.88283682, 45.29004955, 46.69726228, 48.104475  ,
#         49.51168773, 50.91890046, 52.32611319, 53.73332592, 55.14053865,
#         56.54775138, 57.95496411, 59.36217684, 60.76938957, 62.1766023 ,
#         63.58381503]),
#  <BarContainer object of 20 artists>)

# %%
Nopoblado['porcenhom'] = (Nopoblado['Poblacion Hombre'] / Nopoblado['Poblacion Total'])*100
Poblado['porcenhom'] = (Poblado['Poblacion Hombre'] / Poblado['Poblacion Total'])*100

Nopoblado['porcenmuje'] = (Nopoblado['Poblacion Mujer'] / Nopoblado['Poblacion Total'])*100
Poblado['porcenmuje'] = (Poblado['Poblacion Mujer'] / Poblado['Poblacion Total'])*100

fig, (ax, ax1) = plt.subplots(1, 2, figsize=(6,6))

ax.hist((Nopoblado['porcenhom'], Nopoblado['porcenmuje']), bins = 20)
#ax.hist(Nopoblado['porcenmuje'], bins = 20)

ax1.hist((Poblado['porcenhom'], Poblado['porcenmuje']), bins = 20)
#ax2.hist(Poblado['porcenmuje'], bins = 20)
# Out:
# /tmp/ipykernel_3952/3110750732.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Nopoblado['porcenhom'] = (Nopoblado['Poblacion Hombre'] / Nopoblado['Poblacion Total'])*100
# /tmp/ipykernel_3952/3110750732.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Poblado['porcenhom'] = (Poblado['Poblacion Hombre'] / Poblado['Poblacion Total'])*100
# /tmp/ipykernel_3952/3110750732.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
fig, (ax, ax1) = plt.subplots(1, 2, figsize=(6,6))

ax.hist(Nopoblado['porcenhom'], bins = 20, color='green', alpha = .5)
ax.hist(Nopoblado['porcenmuje'], bins = 20, alpha = .5)

ax1.hist(Poblado['porcenhom'], bins = 20, color='green', alpha = .5)
ax1.hist(Poblado['porcenmuje'], bins = 20, alpha = .5)
# Out:
# (array([3.000e+00, 0.000e+00, 1.000e+00, 6.000e+00, 2.300e+01, 4.000e+01,
#         6.100e+01, 2.010e+02, 5.360e+02, 1.179e+03, 1.212e+03, 3.790e+02,
#         7.400e+01, 1.300e+01, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([35.43956044, 36.84677317, 38.2539859 , 39.66119863, 41.06841136,
#         42.47562409, 43.88283682, 45.29004955, 46.69726228, 48.104475  ,
#         49.51168773, 50.91890046, 52.32611319, 53.73332592, 55.14053865,
#         56.54775138, 57.95496411, 59.36217684, 60.76938957, 62.1766023 ,
#         63.58381503]),
#  <BarContainer object of 20 artists>)

# %%
Nopoblado['porcennaci'] = (Nopoblado['Nacimientos'] / Nopoblado['Poblacion Total'])*100
Poblado['porcennaci'] = (Poblado['Nacimientos'] / Poblado['Poblacion Total'])*100

Nopoblado['porcendefu'] = (Nopoblado['Defunciones'] / Nopoblado['Poblacion Total'])*100
Poblado['porcendefu'] = (Poblado['Defunciones'] / Poblado['Poblacion Total'])*100

fig, (ax, ax1) = plt.subplots(1, 2, figsize=(6,6))

ax.hist(Nopoblado['porcennaci'], bins = 20, color='green', alpha = .5)
ax.hist(Nopoblado['porcendefu'], bins = 20, alpha = .5)

ax1.hist(Poblado['porcennaci'], bins = 20, color='green', alpha = .5)
ax1.hist(Poblado['porcenmuje'], bins = 20, alpha = .5)
# Out:
# /tmp/ipykernel_3952/140737403.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Nopoblado['porcennaci'] = (Nopoblado['Nacimientos'] / Nopoblado['Poblacion Total'])*100
# /tmp/ipykernel_3952/140737403.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Poblado['porcennaci'] = (Poblado['Nacimientos'] / Poblado['Poblacion Total'])*100
# /tmp/ipykernel_3952/140737403.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
fig, (ax, ax1) = plt.subplots(1, 2, figsize=(6,6))

ax.hist(Nopoblado['Nacimientos'], bins = 20, color='green', alpha = .5)
ax.hist(Nopoblado['Defunciones'], bins = 20, alpha = .5)
ax.set_yscale('symlog')
ax1.hist(Poblado['Nacimientos'], bins = 20, color='green', alpha = .5)
ax1.hist(Poblado['Defunciones'], bins = 20, alpha = .5)
ax1.set_yscale('symlog')

# %%
fig, (ax, ax1) = plt.subplots(1, 2, figsize=(6,6))

ax.hist(Nopoblado['Nº Hombres Extranjeros'], bins = 20, color='green', alpha = .5)
ax.hist(Nopoblado['Nº Mujeres Extranjeras'], bins = 20, alpha = .5)
ax.set_yscale('symlog')
ax1.hist(Poblado['Nº Hombres Extranjeros'], bins = 20, color='green', alpha = .5)
ax1.hist(Poblado['Nº Mujeres Extranjeras'], bins = 20, alpha = .5)
ax1.set_yscale('symlog')

# %%
print(Despoblacion['Altitud Municipios'].mean())
print(Despoblacion['Altitud Municipios'].median())

print(f"Skewness: {Despoblacion['Altitud Municipios'].skew()}")
print(f"Kurtosis: {Despoblacion['Altitud Municipios'].kurt()}")

fig,ax = plt.subplots(figsize=(6,6))
##ax.get_xaxis().get_major_formatter().set_scientific(False)
#plt.gca().set_xscale('log')
ax.hist(Despoblacion['Altitud Municipios'], bins = 40)
#ax.plot(x, normal_pdf)
#ax.set_xlim(40, 60)
ax.set_xlabel('Población Mujeres')
plt.show()
# Out:
# 450.1166700125471
# 440.0
# Skewness: 0.25052616501378433
# Kurtosis: -0.9660493846351463

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(4,4))
#ax.get_xaxis().get_major_formatter().set_scientific(False)
#plt.gca().set_xscale('symlog')
ax1.hist(Nopoblado['Edad >= 65'], bins = 10  )
ax2.hist(Poblado['Edad >= 65'], bins = 10  )
ax1.set_yscale('symlog')
ax2.set_yscale('symlog')
#ax.plot(x, normal_pdf)
#ax.set_xlim(40, 60)
ax2.set_xlabel('Población Mujeres')
plt.show()

# %%
Despoblacion[Despoblacion['Total Contratos']>60000]
# Out:
#      Nombre Provincia Codigo Provincia Nombre Municipio Codigo Municipio  \
# 508         Barcelona               08        Barcelona            08019
# 2269           Madrid               28           Madrid            28079
#
#      Poblacion Total Poblacion Hombre Poblacion Mujer Superficie Km2_x  \
# 508          1615448           767915          847533           100.76
# 2269         3265038          1529842         1735196           605.77
#
#      Densidad Poblacion_x Altitud Municipios Nacimientos Matrimonios  \
# 508              16032.63                 13       14851        5918
# 2269               5389.9                657       32938       12941
#
#      Defunciones Regimen General Regimen Agrario Regimen Mar Regimen Hogar  \
# 508        15433          853132             855        1886         23680
# 2269       26544         1511856            1800        2242         51252
#
#      Regimen Autonomos Regimen Carbon Total Regimen SS Total Contratos  \
# ...

# %%
Nopoblado['Estudios'] = Nopoblado['Estudios Primarios o Secundarios'] + Nopoblado['Estudios Superiones']
Poblado['Estudios'] = Poblado['Estudios Primarios o Secundarios'] + Poblado['Estudios Superiones']


fig, (ax, ax1) = plt.subplots(1, 2, figsize=(6,6))

ax.hist(Nopoblado['Sin Estudios'], bins = 20, color='green', alpha = .5)
ax.hist(Nopoblado['Estudios'], bins = 20, alpha = .5)
ax.set_yscale('symlog')
ax1.set_yscale('symlog')
ax1.hist(Poblado['Sin Estudios'], bins = 20, color='green', alpha = .5)
ax1.hist(Poblado['Estudios'], bins = 20, alpha = .5)
# Out:
# /tmp/ipykernel_3952/3741523108.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Nopoblado['Estudios'] = Nopoblado['Estudios Primarios o Secundarios'] + Nopoblado['Estudios Superiones']
# /tmp/ipykernel_3952/3741523108.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Poblado['Estudios'] = Poblado['Estudios Primarios o Secundarios'] + Poblado['Estudios Superiones']
# (array([3.697e+03, 2.400e+01, 3.000e+00, 1.000e+00, 3.000e+00, 0.000e+00,
# ...

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(4,4))
#ax.get_xaxis().get_major_formatter().set_scientific(False)
#plt.gca().set_xscale('symlog')
ax1.hist(Nopoblado['Total Contratos'], bins = 10  )
ax2.hist(Poblado['Total Contratos'], bins = 10  )
ax1.set_yscale('symlog')
ax2.set_yscale('symlog')
#ax.plot(x, normal_pdf)
#ax.set_xlim(40, 60)
ax2.set_xlabel('Población Mujeres')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(4,4))
#ax.get_xaxis().get_major_formatter().set_scientific(False)
#plt.gca().set_xscale('symlog')
ax1.hist(Nopoblado['Nº Hogares si Internet'], bins = 10  )
ax2.hist(Poblado['Nº Hogares si Internet'], bins = 10  )
ax1.set_yscale('symlog')
ax2.set_yscale('symlog')
#ax.plot(x, normal_pdf)
#ax.set_xlim(40, 60)
ax2.set_xlabel('Población Mujeres')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(4,4))
#ax.get_xaxis().get_major_formatter().set_scientific(False)
#plt.gca().set_xscale('symlog')
ax1.hist(Nopoblado['Regimen General'], bins = 10  )
ax2.hist(Poblado['Regimen General'], bins = 10  )
ax1.set_yscale('symlog')
ax2.set_yscale('symlog')
#ax.plot(x, normal_pdf)
#ax.set_xlim(40, 60)
ax2.set_xlabel('Población Mujeres')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(4,4))
#ax.get_xaxis().get_major_formatter().set_scientific(False)
#plt.gca().set_xscale('symlog')
ax1.hist(Nopoblado['Total Paro Registrado'], bins = 10  )
ax2.hist(Poblado['Total Paro Registrado'], bins = 10  )
ax1.set_yscale('symlog')
ax2.set_yscale('symlog')
#ax.plot(x, normal_pdf)
#ax.set_xlim(40, 60)
ax2.set_xlabel('Población Mujeres')
plt.show()

# %%
Despoblacion[Despoblacion['Total Paro Registrado'] == 1]
# Out:
#     Nombre Provincia Codigo Provincia Nombre Municipio Codigo Municipio  \
# 827          Cáceres               10   Alagón del Río            10903
# 931          Cáceres               10        Vegaviana            10902
#
#     Poblacion Total Poblacion Hombre Poblacion Mujer Superficie Km2_x  \
# 827             871              435             436            14.29
# 931             863              448             415            22.38
#
#     Densidad Poblacion_x Altitud Municipios Nacimientos Matrimonios  \
# 827                60.95                260           9           3
# 931                38.56                258           4           0
#
#     Defunciones Regimen General Regimen Agrario Regimen Mar Regimen Hogar  \
# 827           9              74             107           0             2
# 931           7              27              72           0             0
#
#     Regimen Autonomos Regimen Carbon Total Regimen SS Total Contratos  \
# ...

# %%
Despoblacion['Nº Centros Sanitarios'] = Despoblacion['Nº Centros Sanitarios'] + 1
print(Despoblacion['Nº Centros Sanitarios'].mean())
print(Despoblacion['Nº Centros Sanitarios'].median())

print(f"Skewness: {Despoblacion['Nº Centros Sanitarios'].skew()}")
print(f"Kurtosis: {Despoblacion['Nº Centros Sanitarios'].kurt()}")

fig,ax = plt.subplots(figsize=(6,6))
#ax.get_xaxis().get_major_formatter().set_scientific(False)
#plt.gca().set_xscale('symlog')
ax.hist(Despoblacion['Nº Centros Sanitarios'], bins = 10  )
ax.set_yscale('symlog')
#ax.plot(x, normal_pdf)
#ax.set_xlim(40, 60)
ax.set_xlabel('Población Mujeres')
plt.show()
# Out:
# 3.0271016311166874
# 2.0
# Skewness: 20.533833773869663
# Kurtosis: 629.450141856451

# %%
Despoblacion.head()
# Out:
#   Nombre Provincia Codigo Provincia Nombre Municipio Codigo Municipio  \
# 0         Albacete               02        Abengibre            02001
# 1         Albacete               02         Albacete            02003
# 2         Albacete               02         Albatana            02004
# 3         Albacete               02          Almansa            02009
# 4         Albacete               02           Alpera            02010
#
#   Poblacion Total Poblacion Hombre Poblacion Mujer Superficie Km2_x  \
# 0             902              457             445            30.77
# 1          171390            84288           87102          1126.99
# 2             794              403             391             30.5
# 3           25432            12631           12801           531.82
# 4            2438             1261            1177           178.47
#
#   Densidad Poblacion_x Altitud Municipios Nacimientos Matrimonios Defunciones  \
# ...

# %%
Nopoblado = Despoblacion[Despoblacion['Umbral'] == 0]

# %%
Nopoblado = Despoblacion[Despoblacion['Umbral'] == 0]
Poblado = Despoblacion[Despoblacion['Umbral'] == 1]

# %%
Despoblacion['Nº Centros Sanitarios'] = Despoblacion['Nº Centros Sanitarios'] + 1
print(Despoblacion['Nº Centros Sanitarios'].mean())
print(Despoblacion['Nº Centros Sanitarios'].median())

print(f"Skewness: {Despoblacion['Nº Centros Sanitarios'].skew()}")
print(f"Kurtosis: {Despoblacion['Nº Centros Sanitarios'].kurt()}")

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(4,4))
#ax.get_xaxis().get_major_formatter().set_scientific(False)
#plt.gca().set_xscale('symlog')
ax1.hist(Nopoblado['Nº Centros Sanitarios'], bins = 10  )
ax2.hist(Poblado['Nº Centros Sanitarios'], bins = 10  )
ax1.set_yscale('symlog')
ax2.set_yscale('symlog')
#ax.plot(x, normal_pdf)
#ax.set_xlim(40, 60)
ax2.set_xlabel('Población Mujeres')
plt.show()
# Out:
# 8.027101631116688
# 7.0
# Skewness: 20.533833773869663
# Kurtosis: 629.450141856451

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(4,4))
#ax.get_xaxis().get_major_formatter().set_scientific(False)
#plt.gca().set_xscale('symlog')
ax1.hist(Nopoblado['Nº Centros Educativos'], bins = 10  )
ax2.hist(Poblado['Nº Centros Educativos'], bins = 10  )
ax1.set_yscale('symlog')
ax2.set_yscale('symlog')
#ax.plot(x, normal_pdf)
#ax.set_xlim(40, 60)
ax2.set_xlabel('Población Mujeres')
plt.show()

# %%
Despoblacion['PorcenH'] = (Despoblacion['Poblacion Hombre'] / Despoblacion['Poblacion Total']) *100
Despoblacion['PorcenM'] = (Despoblacion['Poblacion Mujer'] / Despoblacion['Poblacion Total']) *100
splot = sns.relplot(data=Despoblacion,x='Nº Hombres Extranjeros',y='Umbral1')
#splot = sns.relplot(data=Despoblacion ,x='PorcenH',y='PorcenM',style='Umbral1',hue='Umbral1', kind='scatter')
#splot.set(yscale="log")
splot.set(xscale="log")

# %% [markdown]
# ### Diagrama de cajas

# %%
groupby
sns.countplot(data=penguins,x='species',hue='sex')
# Out:
# Umbral1
# Despo       8232
# Pobla    3013349
# Name: Nº Hombres Extranjeros, dtype: int64

# %%
Despobledad = Despoblacion[['Edad < 16', '16 =< Edad =<64', 'Edad >= 65']]
#sns.boxplot(data=penguins,x='species',y='bill_length_mm')

# %%
Despobledad.head()
# Out:
#    Edad < 16  16 =< Edad =<64  Edad >= 65
# 0         75              545         240
# 1      29940           117445       23645
# 2         90              470         230
# 3       4120            17035        4085
# 4        360             1480         560

# %%
#palette=np.array([sns.color_palette('deep')[0],sns.color_palette('deep')[2],sns.color_palette('deep')[3]])
splot = sns.boxplot(x="variable", y="value", data=pd.melt(Despobledad), palette=palette)
splot.set(yscale="log")
plt.show()

# %%
Edadesdesp = Despoblacion[['Edad < 16', '16 =< Edad =<64', 'Edad >= 65']].loc[Despoblacion['Umbral'] == 0 ]
Edadespob = Despoblacion[['Edad < 16', '16 =< Edad =<64', 'Edad >= 65']].loc[Despoblacion['Umbral'] == 1 ]

# %%
fig, axs = plt.subplots(1, 2, figsize=(10,6))
splot = sns.boxplot(x="variable", y="value", data=pd.melt(Edadesdesp), ax=axs[0])
splot1 = sns.boxplot(x="variable", y="value", data=pd.melt(Edadespob), ax=axs[1])
splot.set(yscale="log")
splot1.set(yscale="log")
plt.show()
#sns.regplot(x='value', y='wage', data=df_melt, ax=axs[0])
#sns.regplot(x='value', y='wage', data=df_melt, ax=axs[1])

# %%
Extrandesp = Despoblacion[['Nº Hombres Extranjeros', 'Nº Mujeres Extranjeras']].loc[Despoblacion['Umbral'] == 0 ]
Extranpob = Despoblacion[['Nº Hombres Extranjeros', 'Nº Mujeres Extranjeras']].loc[Despoblacion['Umbral'] == 1 ]

# %%
fig, axs = plt.subplots(1, 2, figsize=(10,6))
splot = sns.boxplot(x="variable", y="value", data=pd.melt(Extrandesp), ax=axs[0])
splot1 = sns.boxplot(x="variable", y="value", data=pd.melt(Extranpob), ax=axs[1])
splot.set(yscale="log")
splot1.set(yscale="log")
plt.show()

# %%
Hogadesp = Despoblacion[['Hogares Unipersonales', 'Hogares Familiares']].loc[Despoblacion['Umbral'] == 0 ]
Hogapob = Despoblacion[['Hogares Unipersonales', 'Hogares Familiares']].loc[Despoblacion['Umbral'] == 1 ]

# %%
fig, axs = plt.subplots(1, 2, figsize=(10,6))
splot = sns.boxplot(x="variable", y="value", data=pd.melt(Hogadesp), ax=axs[0])
splot1 = sns.boxplot(x="variable", y="value", data=pd.melt(Hogapob), ax=axs[1])
splot.set(yscale="log")
splot1.set(yscale="log")
plt.show()

# %%
splot = sns.relplot(data=Despoblacion,x='Poblacion Total',y='Edad < 16',kind='scatter',hue='Umbral1')
splot.set(yscale="log")
splot.set(xscale="log")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(4,4))
ax.scatter(Despoblacion['Poblacion Total'],Despoblacion['Poblacion Total']+1000)
ax.set_xscale('symlog')
ax.set_yscale('symlog')
