# %% [markdown]
# ## Introducción

# %% [markdown]
# ### Evolución población en España

# %%
import pandas as pd
from matplotlib import pyplot as plt
import geopandas as gpd

# %%
Poblacion = pd.read_excel('Poblacion_España.xlsx')

# %%
Poblacion.head()
# Out:
#               Periodo  Total Nacional
# 0  1 de enero de 1971        34040642
# 1  1 de enero de 1972        34408338
# 2  1 de enero de 1973        34800600
# 3  1 de enero de 1974        35177294
# 4  1 de enero de 1975        35569375

# %%
Poblacion['Año'] = Poblacion['Periodo'].str[-4:].astype('int')

Poblacion.head()
# Out:
#               Periodo  Total Nacional   Año
# 0  1 de enero de 1971        34040642  1971
# 1  1 de enero de 1972        34408338  1972
# 2  1 de enero de 1973        34800600  1973
# 3  1 de enero de 1974        35177294  1974
# 4  1 de enero de 1975        35569375  1975

# %%
Poblacion = Poblacion[(Poblacion['Año'] >1990) & (Poblacion['Año'] <=2021)]

Poblacion.head()
# Out:
#                Periodo  Total Nacional   Año
# 20  1 de enero de 1991        38881416  1991
# 21  1 de enero de 1992        39051336  1992
# 22  1 de enero de 1993        39264034  1993
# 23  1 de enero de 1994        39458489  1994
# 24  1 de enero de 1995        39639726  1995

# %%
f, ax = plt.subplots(figsize=(16,5))

plt.bar(Poblacion['Año'], Poblacion['Total Nacional'], color = 'seagreen', width = 0.6)

ax.set_title("Evolución población 1991-2021", fontweight="bold", size=15)
ax.set_xlabel("Años", fontweight="bold", size=12)
ax.set_ylabel("Poblacion", fontweight="bold", size=12)
ax.set_ylim(3e7, 48e6)
ax.tick_params(labelsize=12)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)


plt.show()

# %% [markdown]
# Incremento población en estos 30 años

# %%
Incremento = ((Poblacion['Total Nacional'].loc[50] - Poblacion['Total Nacional'].loc[20])\
                /Poblacion['Total Nacional'].loc[20])*100

Incremento.round(2)
# Out:
# 21.91

# %% [markdown]
# Evolución España zonas urbanas

# %%
ZonasUrbanas = pd.read_excel('Poblacion_Zonas_Urbanas.xls')

# %%
ZonasUrbanas.head(1)
# Out:
#   Country Name Country Code                  Indicator Name  \
# 0        Aruba          ABW  Población urbana (% del total)
#
#       Indicator Code    1960    1961    1962   1963    1964  1965  ...  \
# 0  SP.URB.TOTL.IN.ZS  50.776  50.761  50.746  50.73  50.715  50.7  ...
#
#      2012   2013    2014    2015    2016    2017    2018    2019    2020  \
# 0  42.957  42.99  43.041  43.108  43.192  43.293  43.411  43.546  43.697
#
#      2021
# 0  43.866
#
# [1 rows x 66 columns]

# %%
ZonasUrbanasEspaña = ZonasUrbanas[ZonasUrbanas['Country Code'] == 'ESP']

# %%
ZonasUrbanasEspaña.drop(['Country Code', 'Indicator Name', 'Indicator Code'], axis = 1, inplace = True)
# Out:
# /home/dsc/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
ZonasUrbanasEspaña = ZonasUrbanasEspaña.melt(id_vars='Country Name')

# %%
ZonasUrbanasEspaña.rename({'variable' : 'Año', 'value' : 'PorcentUrban'}, axis = 1, inplace = True)

# %%
ZonasUrbanasEspaña['Año'] = ZonasUrbanasEspaña['Año'].astype('int')

# %%
ZonasUrbanasEspaña = ZonasUrbanasEspaña[ZonasUrbanasEspaña['Año'] % 5 == 0]

# %%
ZonasUrbanasEspaña
# Out:
#    Country Name   Año  PorcentUrban
# 0        España  1960        56.567
# 5        España  1965        61.278
# 10       España  1970        66.038
# 15       España  1975        69.570
# 20       España  1980        72.789
# 25       España  1985        74.213
# 30       España  1990        75.351
# 35       España  1995        75.856
# 40       España  2000        76.262
# 45       España  2005        77.263
# 50       España  2010        78.442
# 55       España  2015        79.602
# 60       España  2020        80.810

# %%
f, ax = plt.subplots(figsize=(16,5))

ax.plot(ZonasUrbanasEspaña['Año'], ZonasUrbanasEspaña['PorcentUrban'], color = 'seagreen',
        linewidth = 3, marker = 'o', markersize = 10)

ax.set_title("Evolución % población residente zonas urbanas", fontweight="bold", size=15)
ax.set_xlabel("Años", fontweight="bold", size=12)
ax.set_ylabel("Porcentaje", fontweight="bold", size=12)
ax.set_ylim(50, 85)
ax.tick_params(labelsize=12)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)


plt.show()

# %% [markdown]
# Zonas urbanas comparativa UE

# %%
path_Europa = 'GeoEU/CNTR_RG_01M_2020_4326.shp'
Mapa = gpd.read_file(path_Europa)
Mapa.head()
# Out:
#   CNTR_ID                 CNTR_NAME             NAME_ENGL  \
# 0      PF       Polynésie Française      French Polynesia
# 1      KI                  Kiribati              Kiribati
# 2      AE  الإمارات العربية المتحدة  United Arab Emirates
# 3      AD                   Andorra               Andorra
# 4      AO                    Angola                Angola
#
#              NAME_FREN ISO3_CODE          SVRG_UN              CAPT EU_STAT  \
# 0  Polynésie française       PYF     FR Territory           Papeete       F
# 1             Kiribati       KIR  UN Member State            Tarawa       F
# 2  Émirats arabes unis       ARE  UN Member State         Abu Dhabi       F
# 3              Andorre       AND  UN Member State  Andorra la Vella       F
# 4               Angola       AGO  UN Member State            Luanda       F
#
#   EFTA_STAT CC_STAT                       NAME_GERM FID  \
# 0         F       F          Französisch-Polynesien  PF
# 1         F       F                        Kiribati  KI
# 2         F       F  Vereinigten Arabischen Emirate  AE
# 3         F       F                         Andorra  AD
# 4         F       F                          Angola  AO
#
#                                             geometry
# 0  MULTIPOLYGON (((-134.46204 -23.36738, -134.476...
# 1  MULTIPOLYGON (((176.84759 -2.67149, 176.84559 ...
# 2  MULTIPOLYGON (((51.59056 24.24298, 51.59787 24...
# 3  POLYGON ((1.44257 42.60367, 1.45615 42.60265, ...
# 4  MULTIPOLYGON (((23.42989 -17.63446, 22.85778 -...

# %% [markdown]
# Nos quedamos solo con los paises que pertenecen a la UE

# %%
MapaUE = Mapa[Mapa['EU_STAT'] == 'T']

# %%
MapaUE.shape
# Out:
# (27, 13)

# %%
MapaUE.head()
# Out:
#    CNTR_ID                CNTR_NAME NAME_ENGL NAME_FREN ISO3_CODE  \
# 13      AT               Österreich   Austria  Autriche       AUT
# 18      BE  Belgien-Belgique-België   Belgium  Belgique       BEL
# 24      BG                 България  Bulgaria  Bulgarie       BGR
# 51      DK                  Danmark   Denmark  Danemark       DNK
# 54      ES                   España     Spain   Espagne       ESP
#
#             SVRG_UN        CAPT EU_STAT EFTA_STAT CC_STAT   NAME_GERM FID  \
# 13  UN Member State      Vienna       T         F       F  Österreich  AT
# 18  UN Member State    Brussels       T         F       F     Belgien  BE
# 24  UN Member State       Sofia       T         F       F   Bulgarien  BG
# 51  UN Member State  Copenhagen       T         F       F    Dänemark  DK
# 54  UN Member State      Madrid       T         F       F     Spanien  ES
#
#                                              geometry
# 13  MULTIPOLYGON (((10.45444 47.55580, 10.47320 47...
# 18  MULTIPOLYGON (((6.02100 50.75429, 6.03977 50.7...
# 24  POLYGON ((22.67516 44.21566, 22.69084 44.20456...
# 51  MULTIPOLYGON (((15.19308 55.32014, 15.19056 55...
# 54  MULTIPOLYGON (((4.09361 40.06178, 4.10332 40.0...

# %% [markdown]
# Cargamos tabla con el dato de zonas urbanas

# %%
ZonasUrbanas = pd.read_excel('Poblacion_Zonas_Urbanas.xls')

# %%
ZonasUrbanas.head()
# Out:
#   Country Name Country Code                  Indicator Name  \
# 0        Aruba          ABW  Población urbana (% del total)
# 1          NaN          AFE  Población urbana (% del total)
# 2   Afganistán          AFG  Población urbana (% del total)
# 3          NaN          AFW  Población urbana (% del total)
# 4       Angola          AGO  Población urbana (% del total)
#
#       Indicator Code       1960       1961       1962       1963       1964  \
# 0  SP.URB.TOTL.IN.ZS  50.776000  50.761000  50.746000  50.730000  50.715000
# 1  SP.URB.TOTL.IN.ZS  14.563810  14.811410  15.069249  15.347976  15.640195
# 2  SP.URB.TOTL.IN.ZS   8.401000   8.684000   8.976000   9.276000   9.586000
# 3  SP.URB.TOTL.IN.ZS  14.705391  15.090123  15.484076  15.897592  16.329208
# 4  SP.URB.TOTL.IN.ZS  10.435000  10.798000  11.204000  11.624000  12.058000
#
#         1965  ...       2012       2013       2014       2015       2016  \
# 0  50.700000  ...  42.957000  42.990000  43.041000  43.108000  43.192000
# 1  15.941282  ...  33.040474  33.476208  33.936959  34.425581  34.894750
# 2   9.904000  ...  24.160000  24.373000  24.587000  24.803000  25.020000
# 3  16.778650  ...  42.925885  43.554094  44.180175  44.805863  45.425066
# 4  12.504000  ...  61.268000  62.002000  62.731000  63.446000  64.149000
#
#         2017       2018       2019       2020       2021
# 0  43.293000  43.411000  43.546000  43.697000  43.866000
# 1  35.358898  35.847596  36.336258  36.828301  37.323697
# 2  25.250000  25.495000  25.754000  26.026000  26.314000
# 3  46.039478  46.649426  47.255413  47.857831  48.454806
# 4  64.839000  65.514000  66.177000  66.825000  67.460000
#
# [5 rows x 66 columns]

# %%
ZonasUrbanas = ZonasUrbanas[['Country Code', '2021']]

ZonasUrbanas.rename({'Country Code' : 'ISO3_CODE'}, axis = 1, inplace = True)

# %%
ZonasUrbanas.head()
# Out:
#   ISO3_CODE       2021
# 0       ABW  43.866000
# 1       AFE  37.323697
# 2       AFG  26.314000
# 3       AFW  48.454806
# 4       AGO  67.460000

# %%
Urbanas = MapaUE.merge(ZonasUrbanas, on = 'ISO3_CODE')

# %%
Urbanas
# Out:
#    CNTR_ID                        CNTR_NAME    NAME_ENGL   NAME_FREN  \
# 0       AT                       Österreich      Austria    Autriche
# 1       BE          Belgien-Belgique-België      Belgium    Belgique
# 2       BG                         България     Bulgaria    Bulgarie
# 3       DK                          Danmark      Denmark    Danemark
# 4       ES                           España        Spain     Espagne
# 5       EE                            Eesti      Estonia     Estonie
# 6       EL                           Ελλάδα       Greece       Grèce
# 7       CY                    Κύπρος-Kıbrıs       Cyprus      Chypre
# 8       CZ                  Česká Republika      Czechia    Tchéquie
# 9       DE                      Deutschland      Germany   Allemagne
# 10      FR                           France       France      France
# 11      FI                    Suomi-Finland      Finland    Finlande
# 12      HR                         Hrvatska      Croatia     Croatie
# 13      HU                     Magyarország      Hungary     Hongrie
# 14      IE                     Ireland-Éire      Ireland     Irlande
# 15      IT                           Italia        Italy      Italie
# 16      LT                          Lietuva    Lithuania    Lituanie
# 17      LU  Luxemburg-Luxembourg-Lëtzebuerg   Luxembourg  Luxembourg
# 18      LV                          Latvija       Latvia    Lettonie
# 19      MT                      Malta-Malta        Malta       Malte
# 20      NL                        Nederland  Netherlands    Pays-Bas
# 21      RO                          România      Romania    Roumanie
# 22      PL                           Polska       Poland     Pologne
# 23      PT                         Portugal     Portugal    Portugal
# 24      SE                          Sverige       Sweden       Suède
# 25      SI                        Slovinsko     Slovenia    Slovénie
# 26      SK                        Slovensko     Slovakia   Slovaquie
#
#    ISO3_CODE          SVRG_UN        CAPT EU_STAT EFTA_STAT CC_STAT  \
# 0        AUT  UN Member State      Vienna       T         F       F
# 1        BEL  UN Member State    Brussels       T         F       F
# 2        BGR  UN Member State       Sofia       T         F       F
# 3        DNK  UN Member State  Copenhagen       T         F       F
# 4        ESP  UN Member State      Madrid       T         F       F
# 5        EST  UN Member State     Tallinn       T         F       F
# 6        GRC  UN Member State      Athens       T         F       F
# 7        CYP  UN Member State     Nicosia       T         F       F
# 8        CZE  UN Member State      Prague       T         F       F
# 9        DEU  UN Member State      Berlin       T         F       F
# 10       FRA  UN Member State       Paris       T         F       F
# 11       FIN  UN Member State    Helsinki       T         F       F
# 12       HRV  UN Member State      Zagreb       T         F       F
# 13       HUN  UN Member State    Budapest       T         F       F
# 14       IRL  UN Member State      Dublin       T         F       F
# 15       ITA  UN Member State        Rome       T         F       F
# 16       LTU  UN Member State     Vilnius       T         F       F
# 17       LUX  UN Member State  Luxembourg       T         F       F
# 18       LVA  UN Member State        Riga       T         F       F
# 19       MLT  UN Member State    Valletta       T         F       F
# 20       NLD  UN Member State   Amsterdam       T         F       F
# 21       ROU  UN Member State   Bucharest       T         F       F
# 22       POL  UN Member State      Warsaw       T         F       F
# 23       PRT  UN Member State      Lisbon       T         F       F
# 24       SWE  UN Member State   Stockholm       T         F       F
# 25       SVN  UN Member State   Ljubljana       T         F       F
# 26       SVK  UN Member State  Bratislava       T         F       F
#
#        NAME_GERM FID                                           geometry  \
# 0     Österreich  AT  MULTIPOLYGON (((10.45444 47.55580, 10.47320 47...
# 1        Belgien  BE  MULTIPOLYGON (((6.02100 50.75429, 6.03977 50.7...
# 2      Bulgarien  BG  POLYGON ((22.67516 44.21566, 22.69084 44.20456...
# 3       Dänemark  DK  MULTIPOLYGON (((15.19308 55.32014, 15.19056 55...
# 4        Spanien  ES  MULTIPOLYGON (((4.09361 40.06178, 4.10332 40.0...
# 5        Estland  EE  MULTIPOLYGON (((28.04191 59.47012, 28.04319 59...
# 6   Griechenland  EL  MULTIPOLYGON (((29.63524 36.11068, 29.63181 36...
# 7         Zypern  CY  MULTIPOLYGON (((34.60609 35.70767, 34.60060 35...
# 8     Tschechien  CZ  POLYGON ((14.82336 50.87055, 14.83161 50.87233...
# 9    Deutschland  DE  MULTIPOLYGON (((10.45444 47.55580, 10.43954 47...
# 10    Frankreich  FR  MULTIPOLYGON (((55.45117 -20.87174, 55.46030 -...
# 11      Finnland  FI  MULTIPOLYGON (((28.92968 69.05191, 28.82917 69...
# 12      Kroatien  HR  MULTIPOLYGON (((16.59680 46.47590, 16.59863 46...
# 13        Ungarn  HU  MULTIPOLYGON (((22.15531 48.40340, 22.15595 48...
# 14        Irland  IE  MULTIPOLYGON (((-6.00177 53.49551, -5.99821 53...
# 15       Italien  IT  MULTIPOLYGON (((13.71419 46.52270, 13.71688 46...
# 16       Litauen  LT  MULTIPOLYGON (((26.63037 55.68067, 26.63108 55...
# 17     Luxemburg  LU  POLYGON ((6.13766 50.12995, 6.13603 50.12441, ...
# 18      Lettland  LV  MULTIPOLYGON (((27.35158 57.51824, 27.36511 57...
# 19         Malta  MT  MULTIPOLYGON (((14.36876 35.99715, 14.37539 35...
# 20   Niederlande  NL  MULTIPOLYGON (((7.20894 53.24306, 7.21142 53.2...
# 21      Rumänien  RO  MULTIPOLYGON (((28.21136 45.46728, 28.22955 45...
# 22         Polen  PL  MULTIPOLYGON (((19.63903 54.45829, 19.64852 54...
# 23      Portugal  PT  MULTIPOLYGON (((-7.40192 37.17483, -7.39622 37...
# 24      Schweden  SE  MULTIPOLYGON (((24.14395 65.71209, 24.14652 65...
# 25     Slowenien  SI  MULTIPOLYGON (((16.59680 46.47590, 16.59501 46...
# 26      Slowakei  SK  MULTIPOLYGON (((22.56684 49.08838, 22.56370 49...
#
#       2021
# 0   58.995
# 1   98.117
# 2   76.025
# 3   88.240
# 4   81.056
# 5   69.415
# 6   80.038
# 7   66.856
# 8   74.214
# 9   77.544
# 10  81.242
# 11  85.596
# 12  57.878
# 13  72.245
# 14  63.912
# 15  71.346
# 16  68.249
# 17  91.672
# 18  68.421
# 19  94.810
# 20  92.572
# 21  54.329
# 22  60.075
# 23  66.849
# 24  88.238
# 25  55.427
# 26  53.820

# %%
Urbanas = Urbanas.to_crs(epsg=4327)

# %%
lga_json = Urbanas.__geo_interface__

# %%
import plotly.express as px

# %%
tmp = Urbanas.copy()
zmin = Urbanas['2021'].min()
zmax = Urbanas['2021'].max()
fig = px.choropleth_mapbox(tmp, geojson=lga_json,locations=tmp.index,
                           color=tmp['2021'],
                           color_continuous_scale="viridis",
                           range_color=(zmin,zmax),
                           hover_name = Urbanas['NAME_ENGL'],   
                           mapbox_style="carto-positron",
                           zoom = 2.5 ,height = 500,
                           center = dict(lat = 50 , lon = 4),  
                           opacity=0.8,  
                           title = f"<b> % Población zonas urbanas UE</b>")
fig.update_layout(margin=dict(l=30, r=30, t=60, b=30))
fig.update_layout(font=dict(family='sans-serif',size=10))
fig.show('png')
