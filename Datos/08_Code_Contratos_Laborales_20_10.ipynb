# %% [markdown]
# ## Contratos laborales 2020 y 2010
#
# En este notebook procesaremos dos Excel, uno para cada uno de los años.
# Estos archivos contienen el número de contratos laborales por municipios, por tipo de contrato; temporal e indefinido, por sexo, y por sector; agricultura, industria, construcción y servicios.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Contratos laborales 2020
# Obtendremos un DataFrame con la siguiente información:
# - Y2020
# - Nombre Provincia
# - Codigo Provincia
# - Nombre Municipio
# - Codigo Municipio
# - Total Contratos
# - Contratos iniciales indefinidos hombres
# - Contratos iniciales temporales hombres
# - Contratos convertidos en indefinidos hombres
# - Contratos iniciales indefinidos mujeres
# - Contratos iniciales temporales mujeres
# - Contratos convertidos en indefinidos mujeres
# - Contratos  Agricultura
# - Contratos  Industria
# - Contratos Construcción
# - Contratos  Servicios

# %%
ContratosLaborales20 = pd.read_excel('08_Input_Contratos_Laborales_20.xls',dtype='object')
ContratosLaborales20.head()
# Out:
#     Año Código de CA Comunidad Autónoma Codigo Provincia    Provincia  \
# 0  2020           16         País Vasco                1  Araba/Álava
# 1  2020           16         País Vasco                1  Araba/Álava
# 2  2020           16         País Vasco                1  Araba/Álava
# 3  2020           16         País Vasco                1  Araba/Álava
# 4  2020           16         País Vasco                1  Araba/Álava
#
#   Codigo Municipio         Municipio Total Contratos  \
# 0            01001  Alegría-Dulantzi              34
# 1            01002           Amurrio             279
# 2            01003           Aramaio              14
# 3            01004        Artziniega              30
# 4            01006           Armiñón               5
#
#   Contratos iniciales indefinidos hombres  \
# 0                                       2
# 1                                       5
# 2                                       1
# 3                                       0
# ...

# %%
ContratosLaborales20.drop(['Código de CA', 'Comunidad Autónoma', 'Codigo Provincia', 'Provincia', ' Municipio'], axis=1, inplace=True)

# %% [markdown]
# Cargamos la tabla 01_Output_ProvMun_20.xlsx para posteriormente realizar el merge con ContratosLaborales20:

# %%
ProvMun = pd.read_excel('01_Output_ProvMun_20.xlsx', dtype='object') 
ProvMun.head()
# Out:
#   Nombre Provincia Codigo Provincia     Nombre Municipio Codigo Municipio
# 0      Araba/Álava               01  Agurain/Salvatierra            01051
# 1      Araba/Álava               01     Alegría-Dulantzi            01001
# 2      Araba/Álava               01              Amurrio            01002
# 3      Araba/Álava               01                Añana            01049
# 4      Araba/Álava               01              Aramaio            01003

# %%
ContratosLaborales20 = ContratosLaborales20.merge(ProvMun, on='Codigo Municipio')
ContratosLaborales20.head()
# Out:
#     Año Codigo Municipio Total Contratos  \
# 0  2020            01001              34
# 1  2020            01002             279
# 2  2020            01003              14
# 3  2020            01004              30
# 4  2020            01006               5
#
#   Contratos iniciales indefinidos hombres  \
# 0                                       2
# 1                                       5
# 2                                       1
# 3                                       0
# 4                                       0
#
#   Contratos iniciales temporales hombres  \
# 0                                     11
# 1                                    162
# 2                                      5
# 3                                     25
# 4                                      4
#
#   Contratos convertidos en indefinidos hombres  \
# 0                                            4
# 1                                            4
# 2                                            0
# ...

# %%
ContratosLaborales20 = ContratosLaborales20.rename({'Año': 'Y2020'}, axis = 1)
ColNue = ['Y2020','Nombre Provincia', 'Codigo Provincia', 'Nombre Municipio', 'Codigo Municipio', 'Total Contratos',
          'Contratos iniciales indefinidos hombres', 
          'Contratos iniciales temporales hombres','Contratos convertidos en indefinidos hombres', 
          'Contratos iniciales indefinidos mujeres', 'Contratos iniciales temporales mujeres',
          'Contratos convertidos en indefinidos mujeres', 'Contratos  Agricultura','Contratos  Industria', 
          'Contratos Construcción', 'Contratos  Servicios']
ContratosLaborales20 = ContratosLaborales20[ColNue]
ContratosLaborales20.head()
# Out:
#   Y2020 Nombre Provincia Codigo Provincia  Nombre Municipio Codigo Municipio  \
# 0  2020      Araba/Álava               01  Alegría-Dulantzi            01001
# 1  2020      Araba/Álava               01           Amurrio            01002
# 2  2020      Araba/Álava               01           Aramaio            01003
# 3  2020      Araba/Álava               01        Artziniega            01004
# 4  2020      Araba/Álava               01           Armiñón            01006
#
#   Total Contratos Contratos iniciales indefinidos hombres  \
# 0              34                                       2
# 1             279                                       5
# 2              14                                       1
# 3              30                                       0
# 4               5                                       0
#
#   Contratos iniciales temporales hombres  \
# 0                                     11
# 1                                    162
# ...

# %%
ContratosLaborales20.to_excel('08_Output_Contratos_Laborales_20.xlsx', header = True, index = False)

# %% [markdown]
# ### Contratos laborales 2010
# Obtendremos un DataFrame con la siguiente información:
# - Y2010
# - Nombre Provincia
# - Codigo Provincia
# - Nombre Municipio
# - Codigo Municipio
# - Total Contratos
# - Contratos iniciales indefinidos hombres
# - Contratos iniciales temporales hombres
# - Contratos convertidos en indefinidos hombres
# - Contratos iniciales indefinidos mujeres
# - Contratos iniciales temporales mujeres
# - Contratos convertidos en indefinidos mujeres
# - Contratos  Agricultura
# - Contratos  Industria
# - Contratos Construcción
# - Contratos  Servicios

# %%
ContratosLaborales10 = pd.read_excel('08_Input_Contratos_Laborales_10.xls',dtype='object')
ContratosLaborales10.head()
# Out:
#     Año Código de CA Comunidad Autónoma Codigo Provincia    Provincia  \
# 0  2010           16         País Vasco                1  Araba/Álava
# 1  2010           16         País Vasco                1  Araba/Álava
# 2  2010           16         País Vasco                1  Araba/Álava
# 3  2010           16         País Vasco                1  Araba/Álava
# 4  2010           16         País Vasco                1  Araba/Álava
#
#   Codigo Municipio         Municipio Total Contratos  \
# 0            01001  Alegría-Dulantzi              31
# 1            01002           Amurrio             382
# 2            01003           Aramaio               6
# 3            01004        Artziniega               9
# 4            01006           Armiñón               3
#
#   Contratos iniciales indefinidos hombres  \
# 0                                       0
# 1                                       3
# 2                                       0
# 3                                       0
# ...

# %%
ContratosLaborales10.drop(['Código de CA', 'Comunidad Autónoma', 'Codigo Provincia', 'Provincia', ' Municipio'], axis=1, inplace=True)

# %% [markdown]
# Cargamos la tabla 01_Output_ProvMun_10.xlsx para posteriormente realizar el merge con ContratosLaborales10:

# %%
ProvMun = pd.read_excel('01_Output_ProvMun_10.xlsx', dtype='object') 
ProvMun.head()
# Out:
#   Nombre Provincia Codigo Provincia     Nombre Municipio Codigo Municipio
# 0      Araba/Álava               01  Agurain/Salvatierra            01051
# 1      Araba/Álava               01     Alegría-Dulantzi            01001
# 2      Araba/Álava               01              Amurrio            01002
# 3      Araba/Álava               01                Añana            01049
# 4      Araba/Álava               01              Aramaio            01003

# %%
ContratosLaborales10 = ContratosLaborales10.merge(ProvMun, on='Codigo Municipio')
ContratosLaborales10.head()
# Out:
#     Año Codigo Municipio Total Contratos  \
# 0  2010            01001              31
# 1  2010            01002             382
# 2  2010            01003               6
# 3  2010            01004               9
# 4  2010            01006               3
#
#   Contratos iniciales indefinidos hombres  \
# 0                                       0
# 1                                       3
# 2                                       0
# 3                                       0
# 4                                       0
#
#   Contratos iniciales temporales hombres  \
# 0                                     24
# 1                                    276
# 2                                      4
# 3                                      2
# 4                                      0
#
#   Contratos convertidos en indefinidos hombres  \
# 0                                            0
# 1                                           15
# 2                                            0
# ...

# %%
ContratosLaborales10 = ContratosLaborales10.rename({'Año': 'Y2010'}, axis = 1)
ColNue = ['Y2010','Nombre Provincia', 'Codigo Provincia', 'Nombre Municipio', 'Codigo Municipio', 'Total Contratos',
          'Contratos iniciales indefinidos hombres', 
          'Contratos iniciales temporales hombres','Contratos convertidos en indefinidos hombres', 
          'Contratos iniciales indefinidos mujeres', 'Contratos iniciales temporales mujeres',
          'Contratos convertidos en indefinidos mujeres', 'Contratos  Agricultura','Contratos  Industria', 
          'Contratos Construcción', 'Contratos  Servicios']
ContratosLaborales10 = ContratosLaborales10[ColNue]
ContratosLaborales10.head()
# Out:
#   Y2010 Nombre Provincia Codigo Provincia  Nombre Municipio Codigo Municipio  \
# 0  2010      Araba/Álava               01  Alegría-Dulantzi            01001
# 1  2010      Araba/Álava               01           Amurrio            01002
# 2  2010      Araba/Álava               01           Aramaio            01003
# 3  2010      Araba/Álava               01        Artziniega            01004
# 4  2010      Araba/Álava               01           Armiñón            01006
#
#   Total Contratos Contratos iniciales indefinidos hombres  \
# 0              31                                       0
# 1             382                                       3
# 2               6                                       0
# 3               9                                       0
# 4               3                                       0
#
#   Contratos iniciales temporales hombres  \
# 0                                     24
# 1                                    276
# ...

# %%
ContratosLaborales10.to_excel('08_Output_Contratos_Laborales_10.xlsx', header = True, index = False)
