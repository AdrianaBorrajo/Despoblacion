# %% [markdown]
# ## Sucursales bancarias 2020
#
# En este notebook utilizaremos web scraping para extraer el número de sucursales bancarias que había por municipio en el año 2020.
# Obtendremos un DataFrame con la siguiente información:
#    - Y2020
#    - Nombre Provincia
#    - Codigo Provincia
#    - Nombre municipio
#    - Código municipio
#    - Nº Sucursales Bancarias

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
import time
import glob

# %% [markdown]
# Definimos la página a scrapear y ruta de descarga del chromedriver:

# %%
website = 'https://serviciostelematicosext.hacienda.gob.es/SGFAL/CONPREL'

# %%
path = '/home/dsc/Downloads/chromedriver'

# %% [markdown]
# Habilitar permisos múltiples descargas

# %%
option = Options()

option.add_experimental_option(
    "prefs", {"profile.default_content_setting_values.automatic_downloads": 1} #argumento 1: permitir
)

# %% [markdown]
# Definimos variable driver y abrimos Google Chrome:

# %%
driver = webdriver.Chrome(
    options = option, executable_path = path
)

# %%
driver.get(website)

# %% [markdown]
# Seleccionamos el año de extracción de los datos:

# %%
Fecha = Select(driver.find_element_by_xpath('/html/body/div[2]/div[3]/div/div/main/div[5]/div/select'))

# %%
Fecha.select_by_visible_text('2011')

# %% [markdown]
# Del despegable, hay que descargar 19 Excels, uno por CCAA y dos ciudades autónomas:

# %%
 from selenium.webdriver.common.keys import Keys

# %%
CCAA = Select(driver.find_element_by_id('CCAASeleccionado'))
CCAA.select_by_index(2)
time.sleep(3)
CCAA.deselect_all()
time.sleep(3)
CCAA = Select(driver.find_element_by_id('CCAASeleccionado'))
CCAA.select_by_index(3)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# /tmp/ipykernel_2309/1456815388.py in <module>
# ----> 1 CCAA = Select(driver.find_element_by_id('CCAASeleccionado'))
#       2 CCAA.select_by_index(2)
#       3 time.sleep(3)
#       4 CCAA.deselect_all()
#       5 time.sleep(3)
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_id(self, id_)
#     358             element = driver.find_element_by_id('foo')
#     359         """
# --> 360         return self.find_element(by=By.ID, value=id_)
#     361
#     362     def find_elements_by_id(self, id_):
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="CCAASeleccionado"]"}
#   (Session info: chrome=106.0.5249.119)

# %%
CCAA = Select(driver.find_element_by_id('CCAASeleccionado'))
for i in range(2, 4):
    CCAA.select_by_index(i)
    time.sleep(3)
    CCAA.deselect_by_index(i)
    time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# /tmp/ipykernel_2309/517876953.py in <module>
# ----> 1 CCAA = Select(driver.find_element_by_id('CCAASeleccionado'))
#       2 for i in range(2, 4):
#       3     CCAA.select_by_index('i')
#       4     time.sleep(3)
#       5     CCAA.deselect_by_index('i')
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_id(self, id_)
#     358             element = driver.find_element_by_id('foo')
#     359         """
# --> 360         return self.find_element(by=By.ID, value=id_)
#     361
#     362     def find_elements_by_id(self, id_):
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=106.0.5249.119)

# %%
for i in range(2, 4):
    Fecha = Select(driver.find_element_by_xpath('/html/body/div[2]/div[3]/div/div/main/div[5]/div/select'))
    Fecha.select_by_visible_text('2011')
    CCAA = Select(driver.find_element_by_id('CCAASeleccionado'))
    Descargar = driver.find_element_by_xpath('/html/body/div[2]/div[3]/div/div/main/div[7]/div[1]/select/option['+str(i)+']')
    Descargar.click()
    time.sleep(3)

# %%
driver.quit()

# %% [markdown]
# Generamos un DataFrame concatenando los archivos de cada una de las CCAA y ciudades autónomas.
# Descartamos de cada uno de los Excel las primeras filas por contener información no necesaria:

# %%
dfLista = []
ruta = '/home/dsc/Downloads/' 
Excel_files = glob.glob(ruta + "EP2011C01/*.xls")
count = 0

for file in Excel_files:
    with open(file, 'r', encoding='latin1') as f:
        TotalLineas = 0
        for linea in f:
            TotalLineas+= 1
        count += 1
        if count == 1: # primer cvs tiene encabezado
            Inicio = TotalLineas-6
        else: # resto de csv se procesan sin encabezado
            Inicio = TotalLineas-7
           
        df = pd.read_Excel(file, encoding='latin1', skiprows = range(Inicio, TotalLineas), sep = ';', 
            usecols = [' Cód. Provincia ', ' Cód. Municipio ', ' Municipio ', ' Nº de oficinas ']) 
        dfLista.append(df)
        
SucursalesBancarias20 = pd.concat(dfLista, ignore_index = True)

# %%
dfLista = []
ruta = '/home/dsc/Downloads/' 
Excel_files = glob.glob(ruta + "/*.xls")
for file in Excel_files:
    print(file)
    xl = pd.ExcelFile(file)
    sheet_names = xl.sheet_names 
    last_sheet = sheet_names[-1]
    df = pd.read_excel(file, skiprows = range(0, 6), sheet_name = last_sheet)
    dfLista.append(df)
df = pd.concat(dfLista, ignore_index = True)
# Out:
# /home/dsc/Downloads/EP2011C01.xls
# /home/dsc/Downloads/EP2011C01 (1).xls

# %%
df
# Out:
#       Prov  Corp Tipo                                             Nombre  \
# 0        4     0    D  Diputación Prov. de Almería                   ...
# 1        4     1    A  Abla                                          ...
# 2        4     2    A  Abrucena                                      ...
# 3        4     3    A  Adra                                          ...
# 4        4     4    A  Albánchez                                     ...
# ...    ...   ...  ...                                                ...
# 1553    41   101    A  Villaverde del Río                            ...
# 1554    41   102    A  Viso del Alcor (El)                           ...
# 1555    41   901    A  Cañada Rosal                                  ...
# 1556    41   902    A  Isla Mayor                                    ...
# 1557    41   903    A  Cuervo de Sevilla (El)                        ...
#
#       Pobla 2010 Estado Inf. (*)  Impuestos directos  Impuestos indirectos  \
# 0            NaN               C          7715560.00            6742120.00
# 1         1480.0               C           336000.00             180100.00
# 2         1391.0               C           197200.00              11000.00
# 3        24512.0               C          5559000.00             150000.00
# 4          823.0               C           157600.00              31600.00
# ...          ...             ...                 ...                   ...
# 1553      7544.0               C          1190201.20             129965.05
# 1554     18828.0               C          4018817.69              19441.21
# 1555      3262.0               C           568000.00              89262.00
# 1556      5915.0               C          1496000.00              50000.00
# 1557      8660.0               C          1653000.00              50000.00
#
#       Tasas, precios públicos y otros ingresos  Transferencias corrientes  \
# 0                                   9156268.71               1.043422e+08
# 1                                    206100.00               4.812000e+05
# 2                                    190300.00               5.070000e+05
# 3                                   4218000.00               7.917000e+06
# 4                                     45600.00               3.600410e+05
# ...                                        ...                        ...
