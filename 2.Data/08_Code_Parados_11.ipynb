# %% [markdown]
# ## Parados 2011
# En este notebook procesaremos un .xlsx que contiene el paro registrado por municipios y sexo.
#
# Obtendremos un DataFrame con la siguiente información:
# - Codigo Municipio
# - Total Paro Registrado
# - Parados Hombres
# - Parados Mujeres

# %%
import pandas as pd

# %%
Parados11 = pd.read_excel('08_Input_Parados_11.xlsx',dtype = {'Codigo Municipio' : str})

Parados11.head()
# Out:
#   Codigo Municipio         Municipio  Suma de total Paro Registrado  \
# 0            01001  Alegría-Dulantzi                            175
# 1            01002           Amurrio                            720
# 2            01003           Aramaio                             23
# 3            01004        Artziniega                            131
# 4            01006           Armiñón                             10
#
#    Suma de Paro hombre edad < 25  Suma de Paro hombre edad 25 -45   \
# 0                              8                                51
# 1                             38                               172
# 2                              0                                 7
# 3                              6                                34
# 4                              0                                 4
#
#    Suma de Paro hombre edad >=45  Suma de Paro mujer edad < 25  \
# 0                             27                             5
# 1                            120                            25
# 2                              5                             1
# 3                             22                             4
# 4                              0                             0
#
#    Suma de Paro mujer edad 25 -45   Suma de Paro mujer edad >=45  \
# 0                               64                            20
# 1                              192                           173
# 2                                6                             4
# 3                               42                            23
# 4                                3                             3
#
#    Suma de Paro Agricultura  Suma de Paro Industria  \
# 0                         2                      40
# 1                         8                     131
# 2                         0                      10
# 3                         1                      23
# 4                         0                       3
#
#    Suma de Paro Construcción  Suma de Paro Servicios  \
# 0                         12                     106
# 1                         83                     433
# 2                          0                      12
# 3                         11                      83
# 4                          1                       6
#
#    Suma de Paro Sin empleo Anterior
# 0                                15
# 1                                65
# 2                                 1
# 3                                13
# 4                                 0

# %% [markdown]
# Calculamos el total de parados hombres y mujeres

# %%
Parados11['Parados Hombres'] = Parados11['Suma de Paro hombre edad < 25'] + Parados11['Suma de Paro hombre edad 25 -45 '] +\
                              Parados11['Suma de Paro hombre edad >=45']

Parados11['Parados Mujeres'] = Parados11['Suma de Paro mujer edad < 25'] + Parados11['Suma de Paro mujer edad 25 -45 '] +\
                              Parados11['Suma de Paro mujer edad >=45']

Parados11.head()
# Out:
#   Codigo Municipio         Municipio  Suma de total Paro Registrado  \
# 0            01001  Alegría-Dulantzi                            175
# 1            01002           Amurrio                            720
# 2            01003           Aramaio                             23
# 3            01004        Artziniega                            131
# 4            01006           Armiñón                             10
#
#    Suma de Paro hombre edad < 25  Suma de Paro hombre edad 25 -45   \
# 0                              8                                51
# 1                             38                               172
# 2                              0                                 7
# 3                              6                                34
# 4                              0                                 4
#
#    Suma de Paro hombre edad >=45  Suma de Paro mujer edad < 25  \
# 0                             27                             5
# 1                            120                            25
# 2                              5                             1
# 3                             22                             4
# 4                              0                             0
#
#    Suma de Paro mujer edad 25 -45   Suma de Paro mujer edad >=45  \
# 0                               64                            20
# 1                              192                           173
# 2                                6                             4
# 3                               42                            23
# 4                                3                             3
#
#    Suma de Paro Agricultura  Suma de Paro Industria  \
# 0                         2                      40
# 1                         8                     131
# 2                         0                      10
# 3                         1                      23
# 4                         0                       3
#
#    Suma de Paro Construcción  Suma de Paro Servicios  \
# 0                         12                     106
# 1                         83                     433
# 2                          0                      12
# 3                         11                      83
# 4                          1                       6
#
#    Suma de Paro Sin empleo Anterior  Parados Hombres  Parados Mujeres
# 0                                15               86               89
# 1                                65              330              390
# 2                                 1               12               11
# 3                                13               62               69
# 4                                 0                4                6

# %%
Parados11 = Parados11[['Codigo Municipio', 'Suma de total Paro Registrado', 'Parados Hombres', 'Parados Mujeres']]
Parados11.rename({'Suma de total Paro Registrado' : 'Total Paro Registrado'}, axis = 1, inplace = True)

Parados11.head()
# Out:
#   Codigo Municipio  Total Paro Registrado  Parados Hombres  Parados Mujeres
# 0            01001                    175               86               89
# 1            01002                    720              330              390
# 2            01003                     23               12               11
# 3            01004                    131               62               69
# 4            01006                     10                4                6

# %%
Parados11.to_csv('08_Output_Parados_11.csv', header = True, index = False)
