# %% [markdown]
# ## Parados 2011
# En este notebook procesaremos un .xlsx que contiene el paro registrado por municipios, sexo, edad; <25, 25-45, >=45, y sector de actividad económica; agricultura, industria, construcción, servicios y parados de larga duración.
#
# Obtendremos un DataFrame con la siguiente información:
# - Codigo Municipio
# - Paro hombre edad < 25
# - Paro hombre edad 25-45
# - Paro hombre edad >=45
# - Paro mujer edad < 25
# - Paro mujer edad 25-45
# - Paro mujer edad >=45
# - Paro Agricultura
# - Paro Industria
# - Paro Construcción
# - Paro Servicios
# - Paro Sin empleo Anterior

# %%
import pandas as pd

# %%
Parados11 = pd.read_excel('08_Input_Parados_11.xlsx',dtype='object')
Parados11.head()
# Out:
#   Codigo Municipio         Municipio Suma de total Paro Registrado  \
# 0            01001  Alegría-Dulantzi                          1992
# 1            01002           Amurrio                          8393
# 2            01003           Aramaio                           322
# 3            01004        Artziniega                          1690
# 4            01006           Armiñón                           139
#
#   Suma de Paro hombre edad < 25 Suma de Paro hombre edad 25 -45   \
# 0                            86                              552
# 1                           535                             1816
# 2                             2                               69
# 3                           101                              413
# 4                             5                               45
#
#   Suma de Paro hombre edad >=45 Suma de Paro mujer edad < 25  \
# 0                           297                           97
# ...

# %%
Parados11.drop([' Municipio'], axis=1, inplace=True)
Parados11.head()
# Out:
#   Codigo Municipio Suma de total Paro Registrado  \
# 0            01001                          1992
# 1            01002                          8393
# 2            01003                           322
# 3            01004                          1690
# 4            01006                           139
#
#   Suma de Paro hombre edad < 25 Suma de Paro hombre edad 25 -45   \
# 0                            86                              552
# 1                           535                             1816
# 2                             2                               69
# 3                           101                              413
# 4                             5                               45
#
#   Suma de Paro hombre edad >=45 Suma de Paro mujer edad < 25  \
# 0                           297                           97
# 1                          1391                          337
# 2                           106                            5
# ...

# %%
Parados11.to_csv('08_Output_Parados_11.csv', header = True, index = False)
