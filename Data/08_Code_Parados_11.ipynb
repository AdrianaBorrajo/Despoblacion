# %% [markdown]
# ## Parados 2011
# En este notebook procesaremos un .xls que contiene el paro registrado por municipios, sexo, edad; <25, 25-45, >45, y sector de actividad económica; agricultura, industria, construcción, servicios y parados de larga duración.
#
# Obtendremos un DataFrame con la siguiente información:
# - Codigo Municipio
# - Paro hombre edad < 25
# - Paro hombre edad 25-45
# - Paro hombre edad >=45
# - Paro mujer edad < 25
# - Paro mujer edad 25-45
# - Paro mujer edad >=45
# - Paro Agricultura
# - Paro Industria
# - Paro Construcción
# - Paro Servicios
# - Paro Sin empleo Anterior

# %%
import pandas as pd

# %%
Parados11 = pd.read_excel('08_Input_Parados_11.xls',dtype='object')
Parados11.head()
# Out:
#     Año Código de CA Comunidad Autónoma Codigo Provincia    Provincia  \
# 0  2010           16         País Vasco                1  Araba/Álava
# 1  2010           16         País Vasco                1  Araba/Álava
# 2  2010           16         País Vasco                1  Araba/Álava
# 3  2010           16         País Vasco                1  Araba/Álava
# 4  2010           16         País Vasco                1  Araba/Álava
#
#   Codigo Municipio         Municipio total Paro Registrado  \
# 0            01001  Alegría-Dulantzi                   147
# 1            01002           Amurrio                   601
# 2            01003           Aramaio                    30
# 3            01004        Artziniega                   132
# 4            01006           Armiñón                    14
#
#   Paro hombre edad < 25 Paro hombre edad 25 -45  Paro hombre edad >=45  \
# 0                     7                       44                    20
# ...

# %%
Parados11.drop(['Año',
                'Código de CA', 
                'Comunidad Autónoma', 
                'Codigo Provincia', 
                'Provincia', 
                ' Municipio'], axis=1, inplace=True)
Parados11.head()
# Out:
#   Codigo Municipio total Paro Registrado Paro hombre edad < 25  \
# 0            01001                   147                     7
# 1            01002                   601                    31
# 2            01003                    30                     2
# 3            01004                   132                     6
# 4            01006                    14                     1
#
#   Paro hombre edad 25 -45  Paro hombre edad >=45 Paro mujer edad < 25  \
# 0                       44                    20                   10
# 1                      135                   105                   31
# 2                        5                    11                    2
# 3                       34                    16                    3
# 4                        3                     1                    0
#
#   Paro mujer edad 25 -45  Paro mujer edad >=45 Paro Agricultura  \
# 0                      50                   16                3
# ...

# %%
Parados11.to_csv('08_Output_Parados_11.csv', header = True, index = False)
